# %% [markdown]
# ## question 1

# %%
import numpy as np

# %%
a=np.random.random([10,1])

# %%
a
# Out:
# array([[0.91160167],
#        [0.63952776],
#        [0.80027552],
#        [0.15534565],
#        [0.89231892],
#        [0.26105083],
#        [0.49598687],
#        [0.95972262],
#        [0.53569201],
#        [0.10826229]])

# %%
np.mean(a)
# Out:
# 0.5759784146951009

# %% [markdown]
# ## question 2

# %%
b=np.random.random([20,1])

# %%
b
# Out:
# array([[0.82324408],
#        [0.78155964],
#        [0.38123189],
#        [0.64828384],
#        [0.27933754],
#        [0.72603926],
#        [0.56366143],
#        [0.21496006],
#        [0.32398324],
#        [0.47147558],
#        [0.38321997],
#        [0.0800128 ],
#        [0.65211835],
#        [0.56902828],
#        [0.56387693],
#        [0.65632723],
#        [0.72916873],
#        [0.29338187],
#        [0.81245714],
#        [0.40796317]])

# %%
np.var(b)
# Out:
# 0.04389850336214498

# %%
np.std(b)
# Out:
# 0.20951969683575092

# %% [markdown]
# ## question 3

# %%
c=np.random.random([10,20])

# %%
d=np.random.random([20,25])

# %%
e=np.dot(c,d)

# %%
e
# Out:
# array([[4.5609723 , 4.87359688, 5.12777662, 4.09842758, 3.56926994,
#         4.44944053, 5.54623349, 6.54463554, 4.31267245, 5.75460263,
#         3.92964804, 4.19549529, 5.47875409, 5.37781214, 5.28653773,
#         4.70780611, 3.5375922 , 5.04032449, 3.58059361, 5.28733744,
#         5.71524495, 3.65605653, 6.1506986 , 4.46440321, 5.53296337],
#        [5.02005347, 5.1603507 , 5.73799966, 5.02929172, 4.00793412,
#         5.17270812, 4.96227324, 7.00918353, 4.8222737 , 6.07346462,
#         4.76829659, 4.81044242, 5.32955789, 6.42330803, 4.97386151,
#         5.49227564, 4.43039587, 4.94560248, 4.13664173, 5.37430706,
#         5.65694966, 3.86926448, 6.41683219, 5.18733316, 5.69911918],
#        [2.87411687, 3.84325449, 3.85310197, 3.26661288, 2.37135036,
#         3.37588509, 4.09561374, 5.38923833, 4.70344238, 5.01055725,
#         3.90570544, 3.43676078, 4.81419641, 5.07328686, 3.53227423,
#         3.22317628, 2.89031194, 4.8447867 , 2.22296898, 4.67105045,
#         4.09901628, 3.2321217 , 4.77802925, 2.41301434, 4.22020749],
#        [6.06133184, 5.5458604 , 5.40205243, 4.7756943 , 4.4047197 ,
#         5.46584462, 5.07871943, 7.60867057, 5.54507192, 6.32750429,
#         5.32355174, 4.87967916, 6.71222724, 7.50796669, 6.21265399,
#         5.8139432 , 4.40213209, 4.96643264, 4.76626272, 6.06574844,
#         6.14727381, 4.2363063 , 6.50522369, 5.70343013, 5.51653259],
#        [5.85660917, 5.70056014, 6.12720407, 5.2774387 , 4.19205886,
#         5.4502418 , 5.63679288, 6.64061927, 4.67885626, 6.19361379,
#         4.73997816, 4.67446541, 5.46831917, 6.25684795, 5.87405542,
#         5.25703245, 4.79921886, 5.56450377, 4.47019194, 6.30783548,
#         6.3077328 , 4.65020453, 6.67906897, 4.95004067, 5.87972368],
#        [5.78339936, 6.35039726, 5.93478804, 5.15610444, 4.7227245 ,
#         5.8422208 , 5.83848879, 6.84599218, 4.65403012, 6.41308697,
#         4.22250588, 4.5896979 , 5.73393793, 6.31241698, 6.30807366,
#         4.92777868, 4.56358784, 5.94023516, 4.49661016, 5.90957193,
#         6.80339982, 4.30107739, 6.69277929, 5.53326872, 6.33553866],
#        [4.8039023 , 5.18533846, 5.48204271, 5.43730992, 3.22908366,
#         5.45526698, 6.0402359 , 6.41568785, 5.12642456, 6.44056757,
#         4.03767475, 5.0164764 , 5.75687595, 6.72588264, 5.84150408,
#         4.35736361, 4.34828969, 5.37983424, 3.64922731, 5.69613442,
#         5.51691062, 4.19862216, 5.14368652, 4.88129024, 5.12573076],
#        [5.93538681, 4.71034957, 6.41416875, 5.5209117 , 3.83152127,
#         6.50318976, 5.53735372, 6.48314805, 4.77115587, 6.72012903,
#         4.1431933 , 5.21318888, 5.26374381, 6.4506858 , 5.7359585 ,
#         6.01712933, 4.77268494, 5.35986188, 4.51692971, 5.78377992,
#         6.67834778, 5.2178842 , 6.2022441 , 5.58514907, 5.33975784],
#        [4.82486033, 5.01472592, 5.70577705, 4.52077289, 3.68308677,
#         5.27394427, 5.57278158, 6.86951323, 4.65040908, 6.429655  ,
#         3.90887261, 5.0772409 , 5.92390797, 6.56608648, 5.2883246 ,
#         5.33270629, 4.06609014, 5.42567344, 3.97792201, 5.52990389,
#         5.94618354, 4.00492554, 6.16171215, 4.82132807, 5.79421506],
#        [4.04038545, 4.05604144, 5.24034643, 4.39247416, 2.77351229,
#         3.93363064, 5.28978796, 5.49862764, 3.69171473, 5.11907164,
#         3.20010339, 3.79915867, 4.89528575, 5.21748537, 4.57841928,
#         3.92068017, 3.48029832, 4.72608474, 3.62753604, 4.91414524,
#         5.01326876, 3.76422945, 5.54179519, 4.56881626, 4.97366792]])

# %%
e.shape
# Out:
# (10L, 25L)

# %%
np.sum(e)
# Out:
# 1274.874860188405

# %% [markdown]
# ## question 4

# %%
import numpy as np

# %%
w = np.arange(10).reshape(10,1)

# %%
def myfunc(x,axis):
    return 1/(1+ np.exp(-x))

# %%
np.apply_over_axes(myfunc,w,1)
# Out:
# array([[0.5       ],
#        [0.73105858],
#        [0.88079708],
#        [0.95257413],
#        [0.98201379],
#        [0.99330715],
#        [0.99752738],
#        [0.99908895],
#        [0.99966465],
#        [0.99987661]])
