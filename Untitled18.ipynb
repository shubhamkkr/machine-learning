# %%
import numpy as np

# %%
x = np.random.rand(10,1)

# %%
x
# Out:
# array([[0.49110148],
#        [0.90156208],
#        [0.52877703],
#        [0.7975718 ],
#        [0.53482871],
#        [0.65133556],
#        [0.4550874 ],
#        [0.40773752],
#        [0.91317577],
#        [0.01332539]])

# %%
y = np.mean(x)

# %%
y
# Out:
# 0.5694502727309707

# %%
a=np.random.rand(20,1)

# %%
a
# Out:
# array([[0.01240755],
#        [0.66685425],
#        [0.70004386],
#        [0.18935988],
#        [0.54721008],
#        [0.15569329],
#        [0.18795465],
#        [0.21251185],
#        [0.36942676],
#        [0.58054499],
#        [0.17736762],
#        [0.54198872],
#        [0.99755559],
#        [0.71326377],
#        [0.49175434],
#        [0.21123854],
#        [0.35152065],
#        [0.01702825],
#        [0.89248469],
#        [0.74763958]])

# %%
b=np.var(a)

# %%
b
# Out:
# 0.08015294495083858

# %%
c=np.std(a)

# %%
c
# Out:
# 0.2831129544030767

# %%
import math as ma

# %%
p=np.random.rand(10,20)

# %%
p
# Out:
# array([[3.30654292e-01, 8.55876681e-01, 8.32787614e-02, 7.59636095e-01,
#         2.50169429e-01, 2.71118111e-01, 7.69359717e-02, 2.98706477e-01,
#         5.47469416e-01, 9.47355211e-01, 9.77179235e-01, 4.28239032e-01,
#         1.22848477e-01, 1.03358985e-01, 9.78666258e-01, 6.25932883e-01,
#         6.42466829e-01, 6.54841856e-01, 4.30408605e-01, 7.07835817e-01],
#        [2.62518385e-01, 8.27480621e-01, 4.61014183e-01, 4.82196027e-01,
#         6.78811071e-01, 3.46341935e-01, 1.28956288e-03, 1.04998936e-01,
#         1.18063177e-01, 8.35325290e-01, 4.89823105e-01, 8.26223879e-02,
#         7.69395948e-01, 9.11065836e-01, 3.03544046e-03, 4.06566980e-01,
#         3.49314781e-01, 2.64342341e-01, 1.79906207e-01, 5.36556541e-01],
#        [8.32520141e-01, 7.08977433e-02, 4.81148302e-01, 2.94249911e-01,
#         4.86041300e-01, 1.39409672e-01, 8.46830121e-01, 6.77985621e-01,
#         7.60634827e-01, 2.05448117e-01, 3.56812509e-01, 9.77046853e-01,
# ...

# %%
q=np.random.rand(20,25)

# %%
q
# Out:
# array([[2.79630834e-01, 2.69730089e-01, 6.51384635e-01, 4.41229559e-01,
#         8.67626756e-01, 4.81792933e-01, 4.93570340e-01, 2.12579773e-01,
#         5.43620127e-02, 9.57269034e-01, 7.68087411e-01, 8.37800906e-01,
#         6.37338039e-01, 6.47509375e-01, 9.48108516e-01, 1.89666343e-01,
#         5.65689132e-01, 5.87875627e-01, 1.87261221e-01, 8.49656698e-01,
#         1.74509040e-01, 7.42749453e-01, 9.77120549e-01, 6.16818960e-01,
#         3.46168608e-01],
#        [9.64427206e-01, 6.59422844e-01, 4.89182829e-01, 6.86952424e-01,
#         7.69780208e-02, 7.21275119e-02, 3.49937051e-01, 3.20942278e-01,
#         9.89415161e-01, 1.94311783e-01, 1.08631702e-01, 4.21974862e-01,
#         8.11256335e-01, 1.48338492e-01, 7.41714556e-01, 9.05536970e-01,
#         8.58203095e-01, 5.75719541e-01, 6.20765660e-01, 5.96763760e-01,
#         5.92809307e-01, 3.85347758e-01, 7.61579783e-01, 5.55513452e-01,
#         1.01171449e-01],
# ...

# %%
r=np.dot(p,q)

# %% [raw]
# r

# %%
r
# Out:
# array([[4.38829487, 5.7140697 , 4.99205099, 7.56525838, 4.55567251,
#         5.02884202, 3.40765099, 5.65185806, 5.9218286 , 4.56990209,
#         4.47116608, 4.91773077, 4.78097382, 4.94925677, 5.68490931,
#         6.13308174, 5.41753248, 6.37891865, 5.26169365, 6.18660944,
#         5.3891074 , 5.31862229, 6.38151047, 5.22125187, 4.37863872],
#        [3.68822331, 5.42387779, 3.97012096, 6.34941202, 3.85642832,
#         4.07050696, 3.25707973, 3.76763124, 5.81785148, 3.68063368,
#         4.08100254, 3.14890029, 3.58810219, 4.40748492, 4.53001196,
#         5.43795153, 4.57529146, 4.76572944, 4.49371009, 4.27603296,
#         4.26092112, 4.39336419, 5.08717186, 4.25657275, 3.51030427],
#        [4.41506756, 6.44557621, 5.24591779, 7.26339404, 6.16516654,
#         5.68383937, 4.31429611, 5.65376566, 5.46592793, 5.41169425,
#         5.996046  , 4.87998008, 5.48173049, 5.98799244, 6.30814266,
#         6.10264547, 6.12519142, 6.36917433, 5.34980518, 6.62198304,
# ...

# %%
np.shape(r)
# Out:
# (10, 25)

# %%
np.sum(r)
# Out:
# 1286.6882865708083
